# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJunJA/dacon/blob/master/%EB%B2%84%EC%8A%A4%EC%9A%B4%ED%96%89%EC%8B%9C%EA%B0%84%EA%B2%BD%EC%A7%84%EB%8C%80%ED%9A%8Ceda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
submission = pd.read_csv("/content/drive/MyDrive/bus/submission_제출양식.csv")
train = pd.read_csv("/content/drive/MyDrive/bus/train.csv")
test = pd.read_csv("/content/drive/MyDrive/bus/test.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210457 entries, 0 to 210456
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                210457 non-null  int64
#  1   date              210457 non-null  object
#  2   route_id          210457 non-null  int64
#  3   vh_id             210457 non-null  int64
#  4   route_nm          210457 non-null  object
#  5   now_latitude      210457 non-null  float64
#  6   now_longitude     210457 non-null  float64
#  7   now_station       210457 non-null  object
#  8   now_arrive_time   210457 non-null  object
#  9   distance          210457 non-null  float64
#  10  next_station      210457 non-null  object
#  11  next_latitude     210457 non-null  float64
#  12  next_longitude    210457 non-null  float64
#  13  next_arrive_time  210457 non-null  int64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 22.5+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91774 entries, 0 to 91773
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               91774 non-null  int64
#  1   date             91774 non-null  object
#  2   route_id         91774 non-null  int64
#  3   vh_id            91774 non-null  int64
#  4   route_nm         91774 non-null  object
#  5   now_latitude     91774 non-null  float64
#  6   now_longitude    91774 non-null  float64
#  7   now_station      91774 non-null  object
#  8   now_arrive_time  91774 non-null  object
#  9   distance         91774 non-null  float64
#  10  next_station     91774 non-null  object
#  11  next_latitude    91774 non-null  float64
#  12  next_longitude   91774 non-null  float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 9.1+ MB

# %%
train.head()
# Out:
#    id        date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3  2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4  2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#   now_station now_arrive_time  distance     next_station  next_latitude  \
# 0     제주대학교입구             06시     266.0             제대마을      33.457724
# 1        제대마을             06시     333.0            제대아파트      33.458783
# 2       제대아파트             06시     415.0            제주대학교      33.459893
# 3   남국원(아라방면)             06시     578.0  제주여자중고등학교(아라방면)      33.484860
# 4         도호동             07시     374.0              은남동      33.485822
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40
# 3      126.542928                42
# 4      126.490897                64

# %%
test.head()
# Out:
#        id        date   route_id    vh_id route_nm  now_latitude  \
# 0  210457  2019-10-29  405136001  7997025    360-1     33.457724
# 1  210458  2019-10-29  405136001  7997025    360-1     33.458783
# 2  210459  2019-10-29  405136001  7997025    360-1     33.478867
# 3  210460  2019-10-29  405136001  7997025    360-1     33.478850
# 4  210461  2019-10-29  405136001  7997025    360-1     33.480700
#
#    now_longitude  now_station now_arrive_time  distance next_station  \
# 0     126.554014         제대마을             07시     333.0        제대아파트
# 1     126.557353        제대아파트             07시     415.0        제주대학교
# 2     126.483833  한라중학교/부영아파트             08시     417.0      대림2차아파트
# 3     126.488350      대림2차아파트             08시     334.0    연동대림1차아파트
# 4     126.489933    연동대림1차아파트             08시     550.0        케이티앤지
#
#    next_latitude  next_longitude
# 0      33.458783      126.557353
# 1      33.459893      126.561624
# 2      33.478850      126.488350
# 3      33.480700      126.489933
# 4      33.482077      126.485355

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
#운행시간 시각화
#next_arrive_time plot
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import matplotlib.pyplot as plt

train['next_arrive_time'].plot(figsize = (20,10), alpha = 0.4)

plt.title('버스 운행시간')
plt.xlabel('인덱스')
plt.ylabel('운행시간')

plt.show()

# %%
#버스 운행 시간 구간별 데이터셋
a = train[train['next_arrive_time']<20]
b = train[(train['next_arrive_time']>=20) & (train['next_arrive_time']<250)]
c = train[(train['next_arrive_time']>=250) & (train['next_arrive_time']<600)]
d = train[(train['next_arrive_time']>=600) & (train['next_arrive_time']<2300)]
e = train[(train['next_arrive_time']>=2300)]

# %%
x = ['20미만', '20~250', '250~600', '600~2300', '2300이상']
y = [len(a), len(b), len(c), len(d), len(e)]

plt.figure(dpi = 150)
plt.title('버스 운행시간 구간 별 횟수')
plt.xlabel('버스 운행시간 구간')
plt.ylabel('횟수')

plt.bar(x,y)
plt.show()

# %%
plt.figure(dpi = 150)
plt.title('버스 운행시간 히스토그램')
plt.xlabel('운행시간')
plt.ylabel('횟수')

plt.hist(train[train['next_arrive_time']<600]['next_arrive_time'], bins= 20)
plt.show()

# %%
x = ['운행시간<20', '운행시간>=20']
y = [a['distance'].mean(), pd.concat([b,c,d,e])['distance'].mean()]

plt.figure(dpi=150)

plt.title('운행시간과 거리간의 관계')
plt.xlabel('운행시간')
plt.ylabel('거리')

plt.bar(x,y)
plt.show()

# %%
x = ['20~250', '250~600']
y = [b['distance'].mean(), c['distance'].mean()]

plt.figure(dpi=150)

plt.title('운행시간과 거리간의 관계')
plt.xlabel('운행시간')
plt.ylabel('거리')

plt.bar(x,y)
plt.show()

# %%
#이상치 확인을 위해 산점도 그리기
import matplotlib.patches as patches

x = train['distance']
y = train['next_arrive_time']

plt.figure(dpi = 150)

plt.title('거리 vs 운행시간')
plt.xlabel('거리')
plt.ylabel('운행시간')

plt.scatter(x,y, alpha = 0.3)

plt.show()

# %%
import folium

locations = train[(train['distance'] <= 1000) & (train['next_arrive_time'] >= 600)][['next_latitude', 'next_longitude']].values.tolist()

center = [((train[['now_latitude', 'now_longitude']].loc[1].values[0])+(train[['now_latitude', 'now_longitude']].loc[len(train)-1].values[0]))/2, 
          ((train[['now_latitude', 'now_longitude']].loc[1].values[1])+(train[['now_latitude', 'now_longitude']].loc[len(train)-1].values[1]))/2]
          
m = folium.Map(location=center, zoom_start=11, tiles='cartodbpositron')

for location in locations:
    folium.Circle(
        radius=300,
        location=location,
        fill=True
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72ea50e2b8589455db7c78f4fef4fb6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72ea50e2b8589455db7c78f4fef4fb6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72ea50e2b8589455db7c78f4fef4fb6e = L.map(
#                 &quot;map_72ea50e2b8589455db7c78f4fef4fb6e&quot;,
#                 {
#                     center: [33.3531055, 126.53260449999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_89d6de0951b1c5867800880197b33eba = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_72ea50e2b8589455db7c78f4fef4fb6e);
#
#
#             var circle_7428e7e1bc5d751465b1e297a835a93c = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72ea50e2b8589455db7c78f4fef4fb6e);
#
#
#             var circle_ddc97d78e06f2285e15d60ab235ce74e = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72ea50e2b8589455db7c78f4fef4fb6e);
#
#
#             var circle_f1248861900b8a47d9b01d8481eda300 = L.circle(
#                 [33.47626, 126.481417],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72ea50e2b8589455db7c78f4fef4fb6e);
#
#
#             var circle_3f81df7bccc3fcac599834f95ec39de6 = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72ea50e2b8589455db7c78f4fef4fb6e);
#
#
#             var circle_ed7daed90b0ec7298d532ba74c569bb8 = L.circle(
#                 [33.47626, 126.481417],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72ea50e2b8589455db7c78f4fef4fb6e);
#
#
#             var circle_e2760b321d53d9612bc4fe9146699f46 = L.circle(
#                 [33.47626, 126.481417],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;

# %%
#거리가 1000이하일 때, 운행 시간이 600 이상인 데이터 시각화
z = train[(train['distance'] >= 1000) | (train['next_arrive_time'] <= 600)]

x = z['distance']
y = z['next_arrive_time']

plt.figure(dpi = 150)
plt.scatter(x, y, alpha=0.3)

# %%
my_list = list(train['route_nm'].unique()) + list(train['now_station'].unique()) + list(train['next_station'].unique())
my_dict = {text : i for i, text in enumerate(my_list)}
my_dict
# Out:
# {'360-1': 0,
#  '360-2': 1,
#  '360-7': 2,
#  '360-12': 3,
#  '365-21': 4,
#  '365-22': 5,
#  '201-11': 6,
#  '201-12': 7,
#  '201-13': 8,
#  '201-14': 9,
#  '201-15': 10,
#  '201-16': 11,
#  '201-17': 12,
#  '201-18': 13,
#  '201-21': 14,
#  '201-22': 15,
#  '201-24': 16,
#  '201-26': 17,
#  '201-27': 18,
#  '281-1': 19,
#  '281-2': 20,
#  '제주대학교입구': 400,
#  '제대마을': 369,
#  '제대아파트': 370,
#  '남국원(아라방면)': 403,
#  '도호동': 382,
#  '한라중학교/부영아파트': 408,
#  '대림2차아파트': 374,
#  '롯데마트': 402,
#  '원노형': 376,
#  '노형오거리': 377,
#  '남녕고등학교': 378,
#  '한라병원': 379,
#  '삼무공원사거리': 380,
#  '제원아파트': 381,
#  '은남동': 373,
#  '연동주민센터': 383,
#  '제주도청 신제주로터리': 384,
#  '월구마을': 406,
#  '동성마을': 386,
#  '제주버스터미널': 387,
#  '한국병원': 388,
#  '남서광마을입구': 389,
#  '남서광마을': 390,
#  '탐라장애인 종합복지관': 391,
#  '제주시청(아라방면)': 392,
#  '고산동산(아라방면)': 393,
#  '제주지방법원(아라방면)': 394,
#  '아라초등학교': 396,
#  '아라주공아파트': 397,
#  '인다마을': 398,
#  '남국사': 407,
#  '연동대림1차아파트': 375,
#  '케이티앤지': 401,
#  '제주중앙여자고등학교(아라방면)': 395,
#  '제주여자중고등학교(아라방면)': 372,
#  '제주대학교병원': 399,
#  '연동입구': 385,
#  '오라3동': 405,
#  '죽성마을 입구': 404,
#  '제주대학교': 371,
#  '부영아파트': 429,
#  '제주시청(광양방면)': 414,
#  '고산동산(광양방면)': 409,
#  '제주여자중고등학교(광양방면)': 413,
#  '아라동주민센터': 412,
#  '남국원(광양방면)': 411,
#  '제주지방법원(광양방면)': 410,
#  '제주중앙여자고등학교(광양방면)': 415,
#  '웃 인다 마을': 417,
#  '제주대학교 입구': 416,
#  '광양사거리': 418,
#  '홍랑로입구': 419,
#  '용천마을': 420,
#  '동산교': 421,
#  '오라오거리': 422,
#  '명신마을': 423,
#  '월랑마을 남녕고등학교': 424,
#  '제주제일고등학교': 425,
#  '으뜸마을': 426,
#  '탐라도서관': 427,
#  '제주고등학교/중흥S클래스': 428,
#  '보성시장': 430,
#  '시민회관': 431,
#  '중앙로(현대약국)': 432,
#  '관덕정': 433,
#  '서문시장': 434,
#  '용담1동주민센터': 435,
#  '용문사거리': 436,
#  '용문마을': 437,
#  '용문마을회관': 438,
#  '화물청사입구': 439,
#  '중흥S클래스아파트': 441,
#  '시티주유소': 442,
#  '다호마을': 444,
#  '제주국제공항(신제주방면)': 440,
#  '노형초등학교': 452,
#  '제주국제공항(구제주방면)': 445,
#  '월성 마을': 446,
#  '제주중학교/제주향교': 447,
#  '중앙로(국민은행)': 448,
#  '삼성초등학교': 449,
#  '광양': 450,
#  '제주한라대학교': 719,
#  '정존마을': 451,
#  '동광양': 453,
#  '문예회관': 454,
#  '인화초등학교': 455,
#  '천수동': 456,
#  '고으니모르 국립제주박물관': 457,
#  '오현중고등학교': 553,
#  '화북초등학교': 459,
#  '화북남문': 460,
#  '제주동중학교': 461,
#  '삼양초등학교': 555,
#  '원당분화원': 463,
#  '문서교': 647,
#  '조천리': 556,
#  '해양연구소': 643,
#  '함덕비석거리': 467,
#  '함덕농협지소': 468,
#  '함덕리 3구': 469,
#  '함덕환승정류장(함덕해수욕장)': 470,
#  '함덕리(4구)': 471,
#  '911의원': 472,
#  '영등물': 561,
#  '김녕환승정류장(김녕초등학교)': 548,
#  '지경곰': 589,
#  '월정리': 546,
#  '한동리서동': 545,
#  '한동리': 478,
#  '평대리사무소': 641,
#  '평대리동동': 480,
#  '세화리시장2동': 481,
#  '세화환승정류장(세화리)': 482,
#  '세화리구좌농협': 483,
#  '해녀박물관입구': 484,
#  '하도리': 591,
#  '종달리': 543,
#  '종달초등학교': 487,
#  '시흥리': 488,
#  '시흥리사무소': 489,
#  '성산국민체육센터': 490,
#  '성산고입구삼거리': 491,
#  '오조리 입구': 492,
#  '성산고등학교': 493,
#  '성산포 수협': 540,
#  '고성리 구 성산농협': 495,
#  '성산읍사무소': 566,
#  '난산입구': 593,
#  '신산리': 498,
#  '삼달교차로': 568,
#  '신천리취락구조': 539,
#  '신천리': 501,
#  '하천하동': 502,
#  '표선초등학교': 503,
#  '표선환승정류장(표선리 제주은행)': 504,
#  '성산포수협표선지점': 505,
#  '표선오일시장': 506,
#  '그린카센터': 507,
#  '한지동': 538,
#  '가흥동': 509,
#  '세화2리사무소': 510,
#  '가마초등학교': 511,
#  '샤인빌리조트입구': 512,
#  '어촌계입구': 597,
#  '씨사이드홈': 537,
#  '남원읍사무소': 515,
#  '남원포구입구': 516,
#  '남원1리사무소': 517,
#  '동부보건소': 576,
#  '위미3리 마을회관': 605,
#  '위미3리': 520,
#  '대원상동': 604,
#  '뒤통모루': 522,
#  '신례2리교차로': 579,
#  '삼성여자고등학교': 620,
#  '세기아파트': 581,
#  '주공 3 4단지': 526,
#  '동문로터리': 527,
#  '현대산부인과': 528,
#  '청소년문화의집': 529,
#  '구 터미널': 530,
#  '아랑조을거리 입구': 531,
#  '평생학습관': 532,
#  'LH아파트': 602,
#  '서성동': 577,
#  '위미초등학교': 535,
#  '동원산업': 508,
#  '성산리입구': 563,
#  '성산일출봉입구': 541,
#  '오조해녀의집': 494,
#  '하도리면수동': 485,
#  '평대초등학교': 642,
#  '구좌중앙초등학교': 477,
#  '동성동': 475,
#  '김녕리': 549,
#  '조천읍사무소': 607,
#  '대섬입구': 550,
#  '제주버스터미널(가상정류소)': 718,
#  '제주대학교교육대학': 458,
#  '거로 입구': 552,
#  '화북주공아파트': 462,
#  '삼양2동': 554,
#  '신촌초등학교': 465,
#  '조천환승정류장(조천리사무소)': 466,
#  '북촌리해동': 473,
#  '북촌리': 558,
#  '동복리': 585,
#  '동복리관광체험어장': 560,
#  '남흘동': 474,
#  '행원리': 584,
#  '행원농공단지': 562,
#  '계룡동': 479,
#  '성산항입구': 616,
#  '성산리 취락구조': 542,
#  '광치기해변': 564,
#  '성산환승정류장(고성리 한국물류)': 496,
#  '고성리 성산농협': 565,
#  '혼인지입구': 611,
#  '희진주유소': 594,
#  '한지교차로': 569,
#  '토산관광지구입구': 513,
#  '산열이통입구': 570,
#  '수농원': 595,
#  '태흥3리': 613,
#  '태흥초등학교': 514,
#  '광지동': 518,
#  '남원생활체육관': 575,
#  '농협주유소': 578,
#  '창남거리': 525,
#  '비석거리': 580,
#  '광대왓': 534,
#  '하도초등학교': 668,
#  '하도리 서문동': 583,
#  '조천체육관': 557,
#  '주암주택': 586,
#  '동복리휴게소': 609,
#  '김녕해수욕장': 588,
#  '금산목': 590,
#  '하도리동동': 486,
#  '화성농장': 667,
#  '신산환승정류장(성산농협신산지점)': 499,
#  '신흥1번지': 617,
#  '신흥교차로': 572,
#  '태흥3리사무소': 573,
#  '무도동': 574,
#  '종보존연구센터': 521,
#  '위미문화의집': 536,
#  '하례1리입구': 625,
#  '남성마을입구': 533,
#  '서귀포여자고등학교': 630,
#  '고래왓': 582,
#  '만장굴입구': 476,
#  '삼양검문소': 464,
#  '신촌리': 551,
#  '북촌다려마을': 559,
#  '신양리입구': 497,
#  '성산농협종합유통센터': 610,
#  '신풍리하동': 500,
#  '신흥리취락구조': 596,
#  '서소동': 598,
#  '진은동': 614,
#  '상원동': 523,
#  '효돈농협하나로마트': 618,
#  '신성동': 606,
#  '송천교': 571,
#  '세천동': 599,
#  '맹살공원': 635,
#  '상효입구': 662,
#  '토평 보목입구': 619,
#  '남원취락구조': 519,
#  '충혼묘지': 587,
#  '조천초등학교': 646,
#  '하천리취락구조': 621,
#  '표선환승정류장(표선리사무소)': 622,
#  '위미1리사무소': 637,
#  '망장포 입구': 636,
#  '서귀포버스터미널(가상정류소)': 663,
#  '수모루': 629,
#  '여 의 물': 631,
#  '삼매봉': 632,
#  '서귀포시 구 버스터미널': 633,
#  '매일올레시장 7번입구': 627,
#  '삼아아파트': 634,
#  '효돈축구공원': 615,
#  '공천포': 524,
#  '대화동': 624,
#  '표선파출소': 623,
#  '온평초등학교': 567,
#  '성산환승정류장(고성리 회전교차로)': 658,
#  '고성리제주은행': 638,
#  '금붕사': 640,
#  '함덕리 4구': 657,
#  '조천만세동산': 644,
#  '조천환승정류장(조천우체국)': 645,
#  '삼양동주민센터': 666,
#  '국립제주박물관': 648,
#  '우당도서관': 649,
#  '사라봉': 650,
#  '사라봉오거리': 651,
#  '제주여자상업고등학교': 652,
#  '제일교 동문시장입구': 653,
#  '동문성당': 654,
#  '신산로': 655,
#  '성산리': 639,
#  '농협 하나로마트': 660,
#  '오조리': 661,
#  '월정리 용천동': 547,
#  '서귀포동부도서관': 717,
#  '대륜동주민센터': 628,
#  '폭낭사거리': 659,
#  '온평리': 676,
#  '진드르': 608,
#  '하도리창흥동': 592,
#  '원당봉': 665,
#  '보목입구': 626,
#  '고망난돌입구': 612,
#  '난산입구(성산기상대)': 664,
#  '효돈중학교': 673,
#  '효돈초등학교': 669,
#  '신협': 670,
#  '신효동': 671,
#  '월라봉': 672,
#  '평대리서동': 544,
#  '앞동산': 675,
#  '신효': 674,
#  '구좌보건지소': 678,
#  '삼매봉입구': 601,
#  '세화고등학교': 680,
#  '상도마을회관': 715,
#  '오조리상동입구': 683,
#  '고성오일시장': 681,
#  '오조리하동': 682,
#  '사회복지법인 춘강': 684,
#  '산천단': 685,
#  '제주국제대학교': 694,
#  '입석동': 703,
#  '하례환승정류장(하례리입구)': 688,
#  '평안전문요양원': 699,
#  '뒷빌레': 690,
#  '토평마을회관': 691,
#  '답다니': 702,
#  '영천동주민센터': 692,
#  '양지(추모)공원': 687,
#  '제주의료원': 686,
#  '종합사격장': 695,
#  '견월교': 709,
#  '교래입구': 696,
#  '서귀포산업과학고등학교': 689,
#  '공업단지 입구': 705,
#  '오희준 공원': 700,
#  '흙통': 701,
#  '중앙로터리': 693,
#  '제주컨트리클럽': 707,
#  '성판악': 697,
#  '수악교': 704,
#  '고도농원': 713,
#  '한라생태숲': 708,
#  '마방목지': 706,
#  '꽃동산': 710,
#  '법호촌입구': 712,
#  '법호촌 온성학교': 698,
#  '산천단 한국폴리텍대학': 711,
#  '한라산 둘레길': 714,
#  '효례교': 600,
#  '상도리 세화고등학교': 677,
#  '전경대 입구': 716,
#  '하도리 개긋물': 679,
#  '제주한라대학교(종점)': 443,
#  '서귀포버스터미널': 603,
#  '제주버스터미널(종점)': 656}

# %%
# 데이터 전처리 함수
def transform_df(df:pd.DataFrame):

    # my_dict 적용
    df[['route_nm', 'now_station', 'next_station']] = df[['route_nm', 'now_station', 'next_station']].applymap(lambda x:my_dict[x])

    # 시간 정보 str -> int 데이터 타입 변환 함수
    def text_to_time(text:str):
        return int(text[:2])

    # 시간 데이터 타입 변환 함수 적용
    df['now_arrive_time'] = df['now_arrive_time'].map(text_to_time)
  
    return df
 
train = transform_df(train)
test = transform_df(test)

# %%
#운행 시간이 1000초과인 데이터는 이상치라고 판단, 1000이하인 데이터만 사용
train = train[train['next_arrive_time'] <=1000]

# %%
features = train.columns[2:-1]
target = train.columns[-1]

X = train[features]
y = train[target]

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X,y, test_size=0.1, shuffle=False)

#데이터 shape 확인
print(f"X_train.shape : {X_train.shape}")
print(f"y_train.shape : {y_train.shape}")
print(f"X_valid.shape : {X_valid.shape}")
print(f"y_valid.shape : {y_valid.shape}")
# Out:
# X_train.shape : (189231, 11)
# y_train.shape : (189231,)
# X_valid.shape : (21026, 11)
# y_valid.shape : (21026,)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()

# %%
model.fit(X,y)
# Out:
# RandomForestRegressor()

# %%
# 학습된 모델을 이용해 결괏값 예측 후 상위 10개의 값 확인
predict = model.predict(test[features])
print('----------------------예측된 데이터의 상위 10개의 값 확인--------------------\n')
print(predict[:10])
# Out:
# ----------------------예측된 데이터의 상위 10개의 값 확인--------------------
#
# [ 33.46114286  41.89542857 137.49003175  60.47966667 173.22314286
#   28.26266667  72.61147619 204.46188095 130.54635714 115.66764286]

# %%
submission = pd.read_csv("/content/drive/MyDrive/bus/submission_제출양식.csv")
train = pd.read_csv("/content/drive/MyDrive/bus/train.csv")
test = pd.read_csv("/content/drive/MyDrive/bus/test.csv")

# %%
import folium

# 좌표 정보
locations = train[['next_latitude',	'next_longitude']][:5].values.tolist()

# 지도의 중심 좌표 설정
center = [33.35, 126.5]

# 지도 (Map) 그리기
m = folium.Map(location=center, zoom_start=11, tiles='cartodbpositron',)

# 점(Circle) 찍기
for i, location in enumerate(locations):
    folium.Circle(
        radius=50,
        location=location,
        tooltip=train['next_station'].loc[i],
        fill=True
    ).add_to(m)

# 경로(PolyLIne) 추가
folium.PolyLine(locations=locations).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_118797fd28a73e59bd9411cb7f100b50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_118797fd28a73e59bd9411cb7f100b50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_118797fd28a73e59bd9411cb7f100b50 = L.map(
#                 &quot;map_118797fd28a73e59bd9411cb7f100b50&quot;,
#                 {
#                     center: [33.35, 126.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0b3280e35be922f4bb783e01398466b = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_118797fd28a73e59bd9411cb7f100b50);
#
#
#             var circle_d8be622b9602fcd9b876a2a32e2d78ea = L.circle(
#                 [33.457724, 126.554014],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_118797fd28a73e59bd9411cb7f100b50);
#
#
#             circle_d8be622b9602fcd9b876a2a32e2d78ea.bindTooltip(
#                 `&lt;div&gt;
#                      제대마을
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_cf07757c19996de0338243690e35b0c0 = L.circle(
#                 [33.458783000000004, 126.557353],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_118797fd28a73e59bd9411cb7f100b50);
#
#
#             circle_cf07757c19996de0338243690e35b0c0.bindTooltip(
#                 `&lt;div&gt;
#                      제대아파트
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_8efa2e71e9203ee7a6b917a106e527cb = L.circle(
#                 [33.459893, 126.561624],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_118797fd28a73e59bd9411cb7f100b50);
#
#
#             circle_8efa2e71e9203ee7a6b917a106e527cb.bindTooltip(
#                 `&lt;div&gt;
#                      제주대학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_3591c89f5e79d9e86bcb4ee7c2bc3e4f = L.circle(
#                 [33.48486, 126.542928],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_118797fd28a73e59bd9411cb7f100b50);
#
#
#             circle_3591c89f5e79d9e86bcb4ee7c2bc3e4f.bindTooltip(
#                 `&lt;div&gt;
#                      제주여자중고등학교(아라방면)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_e71962a01eaa33743f228b6e47d70281 = L.circle(
#                 [33.485822, 126.490897],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;f

# %%
print(train[train['route_id'] == 405136001]['route_nm'].unique())
print(train[train['route_nm'] == '360-1']['route_id'].unique())
# Out:
# ['360-1']
# [405136001]

# %%
# 예측할 변수 y 할당
y = train['next_arrive_time']

y.head()
# Out:
# 0    24
# 1    36
# 2    40
# 3    42
# 4    64
# Name: next_arrive_time, dtype: int64

# %%
# 'vh_id', 'now_longitude', 'now_arrive_time', 'distance', 'next_longitude' 만 사용
features = ['vh_id', 'now_longitude', 'now_arrive_time', 'distance', 'next_longitude']
# 학습에 사용할 변수 X 할당
X = train[features]

# %%
#데이터 분리

from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size = 0.1, shuffle=False)

# %%
from sklearn.ensemble import RandomForestRegressor

# 모델 선언
model = RandomForestRegressor()

# %%
X.head()
# Out:
#      vh_id  now_longitude now_arrive_time  distance  next_longitude
# 0  7997025     126.551750             06시     266.0      126.554014
# 1  7997025     126.554014             06시     333.0      126.557353
# 2  7997025     126.557353             06시     415.0      126.561624
# 3  7997025     126.543811             06시     578.0      126.542928
# 4  7997025     126.494923             07시     374.0      126.490897

# %%
model = RandomForestRegressor(n_estimators=100, criterion='mse', random_state=42)

# %%
from sklearn.metrics import mean_squared_error

def rmse(pred, real):
    return mean_squared_error(pred, real)**0.5
RMSE = rmse(predict, y_valid)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-ea14c4bfba7f> in <cell line: 5>()
#       3 def rmse(pred, real):
#       4     return mean_squared_error(pred, real)**0.5
# ----> 5 RMSE = rmse(predict, y_valid)
#
# <ipython-input-36-ea14c4bfba7f> in rmse(pred, real)
#       2
#       3 def rmse(pred, real):
# ----> 4     return mean_squared_error(pred, real)**0.5
#       5 RMSE = rmse(predict, y_valid)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      98         correct keyword.
#      99     """
# --> 100     check_consistent_length(y_true, y_pred)
#     101     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     102     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [91774, 21046]
